# %% [markdown]
# ## SEABORN - It provides high level interface for drawing attractive and informative statistical graphs

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
datafile = pd.read_csv("E:/ONLINE COURSES/Side projects/MY PROJECT/Datasets/Toyota.csv",
                    index_col= 0,
                    na_values= ["??", "????"])

# %%
df = datafile

# %%
df
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1096 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1096 non-null   int64
#  1   Age        1096 non-null   float64
#  2   KM         1096 non-null   float64
#  3   FuelType   1096 non-null   object
#  4   HP         1096 non-null   float64
#  5   MetColor   1096 non-null   float64
#  6   Automatic  1096 non-null   int64
#  7   CC         1096 non-null   int64
#  8   Doors      1096 non-null   object
#  9   Weight     1096 non-null   int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 94.2+ KB

# %%
df.dropna(inplace = True) # Removing all missing values

# %%
df.isnull().sum()
# Out:
# Price        0
# Age          0
# KM           0
# FuelType     0
# HP           0
# MetColor     0
# Automatic    0
# CC           0
# Doors        0
# Weight       0
# dtype: int64

# %% [markdown]
# ## 1. SCATTER PLOT

# %%
sns.set(style = "darkgrid") # style = white/ dark/whitegrid/ darkgrid/ ticks  can be used
sns.scatterplot(x = "Age", y = "Price", data = df)

# %%
sns.scatterplot(x = "Age", y = "Price", data = df, color = "red")

# %%
# To include a third variable in the scatter plot using different colour.
sns.set(style = "whitegrid")
sns.scatterplot(x = "Age", y = "Price", data = df, hue = "FuelType")

# %%
# To include a third variable in the scatter plot using different colour and different marker.
sns.set(style = "whitegrid")
sns.scatterplot(x = "Age", y = "Price", data = df, hue = "FuelType", style = "FuelType")

# %%
plt.figure(figsize = (20,10))
sns.scatterplot(x = "Age", y = "Price", data = df, hue = "FuelType", size="FuelType", sizes = (200,100))

# %% [markdown]
# ## 2. LINEPLOT - To show the relationship between two variables with a line

# %%
sns.lineplot(df.Age, df.Price)

# %%
plt.figure(figsize = (20,10))
sns.lineplot(df.Age, df.Price)
plt.show()

# %% [markdown]
# ## 3.REGRESSION PLOT

# %%
sns.regplot(df.Age, df.Price)
plt.show()

# %%
# To remove the regression line.
plt.figure(figsize = (20,10))
sns.regplot(df.Age, df.Price, marker = "*", fit_reg =  False )
plt.show()

# %% [markdown]
# ## 4. LMPLOT - Plot data and regression model fits across a FacetGrid.

# %%
sns.lmplot(x = "Age", y = "Price",data = df, fit_reg = False, hue = "FuelType", legend = True, palette = "Set1", size = 10)

# %% [markdown]
# ## 5.HISTOGRAM

# %%
plt.figure(figsize = (20,10))
sns.distplot(df.Price)
plt.show()

# %%
# To remove the line and increase the bins
plt.figure(figsize = (20,10))
sns.distplot(df.Price, kde = False, bins = 40)
plt.show()

# %% [markdown]
# ## 7.BARPLOT

# %%
plt.figure(figsize = (10,5))
sns.countplot(df.FuelType)
plt.show()

# %% [markdown]
# ## 8. GROUPED BARPLOT

# %%
sns.set(style = "darkgrid")
plt.figure(figsize = (10,5))
sns.countplot(x ="FuelType",data = df, hue = "Automatic")
plt.show()

# %% [markdown]
# ## 9. BOX AND WHISKER PLOT -To visually interpret the  number summary

# %%
# Only numerical variable
plt.figure(figsize = (10,5))
sns.boxplot(y = df["Price"])

# %%
# Numerical vs. Categorical variable
plt.figure(figsize = (10,5))
plt.title("Price vs. FuelType")
sns.boxplot(x = df["FuelType"], y = df["Price"])
plt.show()

# %%
# Numerical vs. 2 Categorical variables
plt.figure(figsize = (10,5))
plt.title("Price vs. FuelType and Automatic")
sns.boxplot(x = df["FuelType"], y = df["Price"], hue = df["Automatic"])
plt.show()

# %%
# Box whiskers plot and histogram
f, (ax_box, ax_hist) = plt.subplots(2, gridspec_kw = {"height_ratios": (.15, .85)})

sns.boxplot(df["Price"], ax = ax_box)
sns.distplot(df["Price"], ax = ax_hist, kde = False)

# %% [markdown]
# ## 10. PAIRWISE PLOT - To show pairwise relationship in the data

# %%
sns.pairplot(data = df)
plt.show()

# %% [markdown]
# ## CATPLOT- To show relationship between a numerical variable and one or more categories

# %%
sns.catplot(x = "Price", y = "FuelType", data = df)
plt.show()

# %%
sns.catplot(x = "Price", y = "FuelType", hue="Automatic", data = df)
plt.show()

# %% [markdown]
# ## HEATMAP - To see the correlation among the variables

# %%
plt.figure(figsize = (15,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.FuelType = df.FuelType.map({"Petrol":1, "Diesel":2})

# %%
df.Doors = df.Doors.map({"three": 3})

# %%
df.corr()
# Out:
#               Price       Age        KM  FuelType        HP  MetColor  \
# Price      1.000000 -0.878407 -0.574720  0.017335  0.309902  0.112041
# Age       -0.878407  1.000000  0.512735 -0.074948 -0.157904 -0.099659
# KM        -0.574720  0.512735  1.000000  0.434944 -0.335285 -0.093825
# FuelType   0.017335 -0.074948  0.434944  1.000000 -0.541903 -0.013189
# HP         0.309902 -0.157904 -0.335285 -0.541903  1.000000  0.064749
# MetColor   0.112041 -0.099659 -0.093825 -0.013189  0.064749  1.000000
# Automatic  0.033081  0.032573 -0.081248 -0.084595  0.013755 -0.013973
# CC         0.165067 -0.120706  0.299993  0.762886  0.053758  0.029189
# Doors           NaN       NaN       NaN       NaN       NaN       NaN
# Weight     0.581198 -0.464299 -0.026271  0.556947  0.086737  0.057142
#
#            Automatic        CC  Doors    Weight
# Price       0.033081  0.165067    NaN  0.581198
# Age         0.032573 -0.120706    NaN -0.464299
# KM         -0.081248  0.299993    NaN -0.026271
# ...
